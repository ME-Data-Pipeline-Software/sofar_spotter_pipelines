# %%
import xarray as xr

ds = xr.open_dataset(
    "../../storage/root/data/cook_inlet.adv-velocity-125ms.a1/cook_inlet.adv-velocity-125ms.a1.20210701.134003.nc"
)

# %%
ds
# Out:
# <xarray.Dataset>
# Dimensions:                    (time: 1396800, beam: 3, dir: 3, x: 3, x*: 3, earth: 3, inst: 3)
# Coordinates:
#   * time                       (time) datetime64[ns] 2021-07-01T13:40:03 ... ...
#   * beam                       (beam) float64 1.0 2.0 3.0
#   * dir                        (dir) object 'streamwise' 'x-stream' 'vert'
#   * earth                      (earth) object 'E' 'N' 'U'
#   * inst                       (inst) object 'X' 'Y' 'Z'
# Dimensions without coordinates: x, x*
# Data variables: (12/32)
#     beam2inst_orientation      (x, x*) float64 ...
#     battery_voltage            (time) float32 ...
#     speed_of_sound             (time) float32 ...
#     heading                    (time) float32 ...
#     pitch                      (time) float32 ...
#     roll                       (time) float32 ...
#     ...                         ...
#     qc_correlation             (beam, time) int32 ...
#     qc_orientation_down        (time) int32 ...
# ...
