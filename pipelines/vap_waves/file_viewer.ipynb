# %%
import xarray as xr

ds_vap = xr.open_dataset(
    "../../storage/root/data/clallam.vap_waves.b1/clallam.vap_waves.b1.20210824.180425.nc"
)

# %%
ds_vap
# Out:
# <xarray.Dataset>
# Dimensions:  (time: 6704446)
# Coordinates:
#   * time     (time) datetime64[ns] 2021-08-24T18:04:25 ... 2021-09-29T19:57:3...
# Data variables:
#     x        (time) float32 ...
#     y        (time) float32 ...
#     z        (time) float32 ...
#     lat      (time) float32 ...
#     lon      (time) float32 ...
#     qc_x     (time) int32 ...
#     qc_y     (time) int32 ...
#     qc_z     (time) int32 ...
#     qc_lat   (time) int32 ...
#     qc_lon   (time) int32 ...
# Attributes:
#     title:         waves
#     description:   Example pipeline processing data taken by a Sofar Spotter ...
#     institution:   Pacific Northwest National Laboratory
#     location_id:   clallam
#     dataset_name:  vap_waves
#     data_level:    b1
#     datastream:    clallam.vap_waves.b1
#     history:       Ran by jmcvey3 at 2023-04-10T15:14:05.214363
#     code_version:  0.0.0-post.12+85c3880.dirty
#     fs:            2.5
