# %%
import xarray as xr

ds = xr.open_dataset(
    "test/data/expected/adcp.current-velocity-1s.a1.20200815.002000.nc"
)

# %%
ds
# Out:
# <xarray.Dataset>
# Dimensions:                   (time: 55000, time_b5: 55000, dirIMU: 3, range_b5: 28, beam: 4, range: 28, dir: 4, earth: 3, inst: 3, q: 4)
# Coordinates:
#   * time                      (time) datetime64[ns] 2020-08-15T00:20:00.50099...
#   * time_b5                   (time_b5) datetime64[ns] 2020-08-15T00:20:00.43...
#   * dirIMU                    (dirIMU) object 'E' 'N' 'U'
#   * range_b5                  (range_b5) float64 1.2 1.7 2.2 ... 13.7 14.2 14.7
#   * beam                      (beam) float64 1.0 2.0 3.0 4.0
#   * range                     (range) float64 1.2 1.7 2.2 2.7 ... 13.7 14.2 14.7
#   * dir                       (dir) object 'E' 'N' 'U1' 'U2'
#   * earth                     (earth) object 'E' 'N' 'U'
#   * inst                      (inst) object 'X' 'Y' 'Z'
#   * q                         (q) object 'w' 'x' 'y' 'z'
# Data variables: (12/72)
#     speed_of_sound            (time) float32 ...
#     temperature               (time) float32 ...
# ...
